# %%
import lp_reader

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = cv2.imread('auti_ista_rez/4.jpg')

# %%
lpr = lp_reader.lp_reader()

# %%
lpr.detect(a)

# %%
lpr.read()
# Out:
# ['ZG-3502-FE']

# %%
plt.imshow(lpr.cropped[1])

# %%
plt.imshow(lpr.car)

# %%
lpr.
