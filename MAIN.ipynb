# %%
import cv2
import matplotlib.pyplot as plt
from read_lp import read_lp
from detect_lp import lp_finder_3
# %matplotlib inline

# %%
car = cv2.imread('1.jpg')

# %%
plt.imshow(car)

# %%
imgs = lp_finder_3(car)

# %%
reads = read_lp(imgs)
print(reads)
print('no of possibilities:', len(reads))
# Out:
# ['OS-707-OM', 'OS-707-GS', 'ZG-707-RA', 'OS-707-SS', 'ZG-707-SS', 'ZG-707-OM', 'OS-707-DM', 'ZG-707-GS', 'OS-707-RA', 'ZG-707-DM']
# no of possibilities: 10
