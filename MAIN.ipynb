# %%
import cv2
import matplotlib.pyplot as plt
from read_lp import read_lp
from detect_lp import lp_finder_3
# %matplotlib inline

# %%
car = cv2.imread('auti_ista_rez/28.jpg')

# %%
plt.imshow(car)

# %%
imgs = lp_finder_3(car)

# %%
plt.figure(figsize=(8,3.5))
for i in range(len(imgs)):
    plt.subplot(3,1,i+1)
    plt.imshow(imgs[i], cmap = 'gray')

# %%
reads = read_lp(imgs)
print(reads)
print('no of possibilities:', len(reads))
# Out:
# []
# no of possibilities: 0
